# %%
import numpy as np
import random
import re
import nltk
import math
from tabulate import tabulate

# %%
def extract_lines(corpus):
    all_lines = list()
    with open(corpus, 'r', encoding = 'latin-1') as rfile:
        for line in rfile:
            all_lines.append(line)
    
    return all_lines

# %%
def tokenize_lines_by_words(lines):
    new_lines = list()
    for line in lines:
        new_line = line.lower()
        new_lines.append(nltk.word_tokenize(new_line))
    
    return new_lines

# %%
def clean_alphabetic_text_lines(lines):
    new_lines = list()
    for line in lines:
        new_line = list()
        for word in line:
            token = list()
            for c in word:
                #[a-záéíóúñü+$]
                if re.match(r'^[a-záéíóúñü+$]', c):
                    token.append(c)
            token = ''.join(token)
            if token != '':
                new_line.append(token)
        new_lines.append(new_line)
        
    return new_lines

# %%
def remove_stop_words(lines):
    stopwords = nltk.corpus.stopwords.words('english')
    clean_lines = list()
    for line in lines:
        clean_line = list()
        for word in line:
            if word not in stopwords:
                clean_line.append(word)
        clean_lines.append(clean_line)
    
    return clean_lines

# %%
def get_X_y(lines):
    X = list()
    y = list()
    for line in lines:
        n = len(line)
        tag = line.pop(n - 1)
        corpus = line
        X.append(corpus)
        y.append(tag)
    return [X, y]

# %%
def transform_tag(y):
    new_y = list()
    for i in y:
        if i == 'spam':
            new_i = 1
        else:
            new_i = 0
        new_y.append(new_i)
    return np.array(new_y)

# %%
def lemmatize_X(X):
    lemmas_X = list()
    tags = ['j', 'n', 'r', 'v']
    wnl = nltk.WordNetLemmatizer()
    for line in X:
        tagged_line = nltk.pos_tag(line)
        #print(tagged_line)
        lemmas_line = list()
        for token in tagged_line:
            tag = token[1]
            if tag in tags:
                lemmatized_token = wnl.lemmatize(token, tag)
            else:
                lemmatized_token = token[0]
            lemmas_line.append(lemmatized_token)
        lemmas_X.append(lemmas_line)
    return lemmas_X

# %%
def get_vocabulary(X):
    words = list()
    for line in X:
        for word in line:
            words.append(word)
    vocabulary = list(sorted(set(words)))
    return vocabulary

# %%
def get_matrix_X(X, vocabulary):
    matrix_X = list()
    for line in X:
        xi = list()
        xi.append(1)
        m = len(line)
        for word in vocabulary:
            if m != 0:
                xi.append(line.count(word) / m) 
            else:
                xi.append(m)
        xi = np.array(xi)
        matrix_X.append(xi)
    matrix_X = np.array(matrix_X)
    return matrix_X.T

# %%
def separateSet(X, Y, test_percentage):
    data_zipped = list(zip(X, Y))
    random.shuffle(data_zipped) # revuelve la data 
    X, Y = zip(*data_zipped) # descomprime el iterable dado

    total_test = math.ceil(len(Y) * test_percentage)
    total_train = len(Y) - total_test

    X_train = X[:total_train]
    X_test = X[total_train:]
    Y_train = Y[:total_train]
    Y_test = Y[total_train:]

    return np.array(X_train), np.array(Y_train), np.array(X_test), np.array(Y_test)

# %%
def initialize_w(n):
    w = np.zeros(n)
    return w

# %%
def get_z(matrix_X, w):
    z = np.dot(matrix_X, w.T)
    return z

# %%
def prediction(z):
    new_Y = np.exp(z) / (1 + np.exp(z))
    return np.array(new_Y)

# %%
def j(Y, prediction):
    sum1 = np.sum(Y * np.log(prediction))
    sum2 = np.sum((1 - Y) * np.log(1 - prediction))
    result = - (sum1 + sum2) / len(Y)
    return result

# %%
def j_partial(matrix_X, Y, prediction):
    result = list()
    for x in matrix_X.T:
        result.append((1 / len(Y)) * np.dot((prediction - Y), x))
    return np.array(result)

# %%
def get_new_w(w, jpartial, alpha):
    #print(w)
    new_w =  w - (alpha * jpartial)
    #print(jpartial)
    #print(new_w)
    return new_w

# %%
def train(matrix_X, Y, w, alpha, iterations = 1000):
    for i in range(iterations):
        z = get_z(matrix_X, w)
        new_Y = prediction(z)
        error = j(Y, new_Y)
        new_w = j_partial(matrix_X, Y, new_Y)
        w = get_new_w(w, new_w, alpha)
        if i % 50 == 0:
            print("In iteration", i, "the cost function is", error)
    return w

# %%
def test(matrix_X, Y, w):
    z = get_z(matrix_X, w)
    Y_pred = prediction(z)

    table = []
    correct = 0
    for i in range(len(Y)):
        #error = abs(100 - (100 / (Y[i]) * Y_pred[i]))
        table.append([Y[i], Y_pred[i]])
        if Y[i] == 1:
            if Y_pred[i] >= 0.5:
                correct += 1
        else:
            if Y_pred[i] < 0.5:
                correct += 1
    
    print(tabulate(table, headers = ['Real','Prediction'], tablefmt = "grid", numalign = "center"))
    print("Cost function: ", j(Y, Y_pred))
    print("Accuracy: ", 100 * correct / len(Y), "%")

# %%
all_lines = extract_lines('./SMS_Spam_Corpus_big.txt')

# %%
random.shuffle(all_lines)

# %%
tokenized_lines = tokenize_lines_by_words(all_lines)

# %%
clean_alphabetic_lines = clean_alphabetic_text_lines(tokenized_lines)

# %%
clean_lines = remove_stop_words(clean_alphabetic_lines)

# %%
X, y = get_X_y(clean_lines)

# %%
Y = transform_tag(y)

# %%
X_lemmatized = lemmatize_X(X)

# %%
vocabulary = get_vocabulary(X_lemmatized)

# %%
matrix_X = get_matrix_X(X_lemmatized, vocabulary)

# %%
X_train, Y_train, X_test, Y_test = separateSet(matrix_X.T, Y, 0.3)

# %%
w = initialize_w(len(vocabulary) + 1)

# %%
alpha = 1

# %%
w_train = train(X_train, Y_train, w, alpha, iterations = 1000)
# Out:
# In iteration 0 the cost function is 0.6931471805599453
# In iteration 50 the cost function is 0.5387671361798929
# In iteration 100 the cost function is 0.5229911035136247
# In iteration 150 the cost function is 0.5084959182117564
# In iteration 200 the cost function is 0.4950816798647765
# In iteration 250 the cost function is 0.48260193798362283
# In iteration 300 the cost function is 0.47094391484849074
# In iteration 350 the cost function is 0.4600172087780294
# In iteration 400 the cost function is 0.4497470835113531
# In iteration 450 the cost function is 0.4400703139914474
# In iteration 500 the cost function is 0.43093250101295
# In iteration 550 the cost function is 0.4222862555691499
# In iteration 600 the cost function is 0.414089914623055
# In iteration 650 the cost function is 0.4063065931063062
# In iteration 700 the cost function is 0.39890345705054076
# In iteration 750 the cost function is 0.3918511483327054
# In iteration 800 the cost function is 0.38512331782559633
# In iteration 850 the cost function is 0.3786962391686183
# In iteration 900 the cost function is 0.372548484588644
# In iteration 950 the cost function is 0.3666606498419427

# %%
w_train
# Out:
# array([-0.84586862, -0.10243896,  1.25264273, ...,  0.06954599,
#        -0.08995992, -3.31383795])

# %%
test(X_test, Y_test, w_train)
# Out:
# +--------+--------------+
# |  Real  |  Prediction  |
# +========+==============+
# |   0    |   0.216678   |
# +--------+--------------+
# |   1    |   0.298314   |
# +--------+--------------+
# |   0    |   0.167838   |
# +--------+--------------+
# |   0    |   0.171542   |
# +--------+--------------+
# |   0    |   0.22034    |
# +--------+--------------+
# |   1    |   0.473647   |
# +--------+--------------+
# |   1    |   0.455939   |
# +--------+--------------+
# |   0    |   0.107805   |
# +--------+--------------+
# |   1    |   0.349365   |
# +--------+--------------+
# |   0    |   0.183693   |
# +--------+--------------+
# |   1    |   0.384735   |
# +--------+--------------+
# |   1    |   0.368457   |
# +--------+--------------+
# |   0    |   0.206097   |
# +--------+--------------+
# |   0    |   0.289687   |
# +--------+--------------+
# |   0    |   0.253813   |
# +--------+--------------+
# |   0    |  0.0361233   |
# +--------+--------------+
# |   1    |   0.394964   |
# +--------+--------------+
# |   0    |   0.152337   |
# +--------+--------------+
# |   0    |    0.3003    |
# +--------+--------------+
# |   0    |  0.0897179   |
# +--------+--------------+
# |   1    |   0.656015   |
# +--------+--------------+
# |   0    |    0.3003    |
# +--------+--------------+
# |   0    |   0.293401   |
# +--------+--------------+
# |   0    |   0.184816   |
# +--------+--------------+
# |   0    |   0.191597   |
# +--------+--------------+
# |   0    |  0.0891624   |
# +--------+--------------+
# |   0    |   0.150777   |
# +--------+--------------+
# |   0    |   0.16129    |
# +--------+--------------+
# |   0    |   0.225412   |
# +--------+--------------+
# |   0    |   0.198363   |
# +--------+--------------+
# |   0    |  0.0678355   |
# +--------+--------------+
# |   0    |   0.190845   |
# +--------+--------------+
# |   0    |   0.253766   |
# +--------+--------------+
# |   0    |   0.117781   |
# +--------+--------------+
# |   0    |   0.228741   |
# +--------+--------------+
# |   0    |  0.0732749   |
# +--------+--------------+
# |   1    |   0.375393   |
# +--------+--------------+
# |   0    |   0.126207   |
# +--------+--------------+
# |   1    |   0.408991   |
# +--------+--------------+
# |   0    |   0.183108   |
# +--------+--------------+
# |   0    |  0.0337251   |
# +--------+--------------+
# |   0    |   0.15882    |
# +--------+--------------+
# |   1    |   0.639993   |
# +--------+--------------+
# |   0    |   0.169953   |
# +--------+--------------+
# |   0    |   0.104791   |
# +--------+--------------+
# |   0    |  0.0765227   |
# +--------+--------------+
# |   1    |   0.326771   |
# +--------+--------------+
# |   1    |   0.44002    |
# +--------+--------------+
# |   0    |   0.162133   |
# +--------+--------------+
# |   0    |  0.0763101   |
# +--------+--------------+
# |   1    |   0.51543    |
# +--------+--------------+
# |   1    |   0.361748   |
# +--------+--------------+
# |   0    |   0.116779   |
# +--------+--------------+
# |   0    |  0.0989991   |
# +--------+--------------+
# |   1    |   0.342554   |
# +--------+--------------+
# |   0    |   0.115724   |
# +--------+--------------+
# |   0    |   0.145174   |
# +--------+--------------+
# |   1    |   0.484695   |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   1    |   0.461042   |
# +--------+--------------+
# |   0    |   0.202189   |
# +--------+--------------+
# |   1    |   0.362443   |
# +--------+--------------+
# |   0    |   0.122028   |
# +--------+--------------+
# |   0    |   0.201257   |
# +--------+--------------+
# |   1    |   0.412517   |
# +--------+--------------+
# |   1    |   0.47595    |
# +--------+--------------+
# |   0    |   0.27138    |
# +--------+--------------+
# |   0    |  0.0512171   |
# +--------+--------------+
# |   0    |   0.25226    |
# +--------+--------------+
# |   0    |    0.3003    |
# +--------+--------------+
# |   0    |   0.28321    |
# +--------+--------------+
# |   0    |   0.152799   |
# +--------+--------------+
# |   0    |   0.183039   |
# +--------+--------------+
# |   0    |   0.217579   |
# +--------+--------------+
# |   0    |   0.143772   |
# +--------+--------------+
# |   0    |   0.287573   |
# +--------+--------------+
# |   1    |   0.55236    |
# +--------+--------------+
# |   0    |   0.348178   |
# +--------+--------------+
# |   0    |   0.325916   |
# +--------+--------------+
# |   1    |   0.399348   |
# +--------+--------------+
# |   0    |   0.12825    |
# +--------+--------------+
# |   0    |   0.195936   |
# +--------+--------------+
# |   0    |   0.216405   |
# +--------+--------------+
# |   1    |   0.527278   |
# +--------+--------------+
# |   0    |    0.2049    |
# +--------+--------------+
# |   0    |   0.152338   |
# +--------+--------------+
# |   1    |   0.308944   |
# +--------+--------------+
# |   0    |   0.18266    |
# +--------+--------------+
# |   0    |  0.0575528   |
# +--------+--------------+
# |   0    |   0.201664   |
# +--------+--------------+
# |   1    |   0.533098   |
# +--------+--------------+
# |   0    |   0.272533   |
# +--------+--------------+
# |   0    |   0.170083   |
# +--------+--------------+
# |   1    |   0.329626   |
# +--------+--------------+
# |   1    |   0.392962   |
# +--------+--------------+
# |   0    |  0.0844819   |
# +--------+--------------+
# |   0    |   0.124581   |
# +--------+--------------+
# |   0    |   0.244183   |
# +--------+--------------+
# |   0    |   0.197362   |
# +--------+--------------+
# |   0    |   0.120385   |
# +--------+--------------+
# |   1    |   0.302672   |
# +--------+--------------+
# |   0    |   0.231273   |
# +--------+--------------+
# |   0    |   0.197563   |
# +--------+--------------+
# |   0    |   0.10419    |
# +--------+--------------+
# |   0    |   0.241571   |
# +--------+--------------+
# |   0    |   0.240514   |
# +--------+--------------+
# |   0    |   0.21585    |
# +--------+--------------+
# |   0    |   0.177372   |
# +--------+--------------+
# |   0    |   0.277077   |
# +--------+--------------+
# |   0    |   0.217235   |
# +--------+--------------+
# |   0    |   0.294162   |
# +--------+--------------+
# |   0    |   0.251985   |
# +--------+--------------+
# |   0    |   0.150479   |
# +--------+--------------+
# |   0    |   0.242757   |
# +--------+--------------+
# |   1    |   0.508346   |
# +--------+--------------+
# |   0    |   0.116774   |
# +--------+--------------+
# |   0    |  0.0776323   |
# +--------+--------------+
# |   0    |   0.13454    |
# +--------+--------------+
# |   0    |   0.128854   |
# +--------+--------------+
# |   0    |   0.275293   |
# +--------+--------------+
# |   0    |   0.216583   |
# +--------+--------------+
# |   0    |   0.193001   |
# +--------+--------------+
# |   1    |   0.476934   |
# +--------+--------------+
# |   0    |   0.229892   |
# +--------+--------------+
# |   0    |   0.251086   |
# +--------+--------------+
# |   0    |   0.176577   |
# +--------+--------------+
# |   0    |   0.222643   |
# +--------+--------------+
# |   0    |   0.206274   |
# +--------+--------------+
# |   0    |   0.115268   |
# +--------+--------------+
# |   0    |   0.208391   |
# +--------+--------------+
# |   1    |   0.312169   |
# +--------+--------------+
# |   0    |   0.226743   |
# +--------+--------------+
# |   0    |   0.246555   |
# +--------+--------------+
# |   0    |   0.147612   |
# +--------+--------------+
# |   0    |   0.415171   |
# +--------+--------------+
# |   1    |   0.394554   |
# +--------+--------------+
# |   0    |   0.141193   |
# +--------+--------------+
# |   1    |   0.397959   |
# +--------+--------------+
# |   0    |   0.226181   |
# +--------+--------------+
# |   0    |   0.151515   |
# +--------+--------------+
# |   0    |   0.173534   |
# +--------+--------------+
# |   1    |   0.47595    |
# +--------+--------------+
# |   1    |   0.291413   |
# +--------+--------------+
# |   1    |   0.473168   |
# +--------+--------------+
# |   0    |   0.155968   |
# +--------+--------------+
# |   1    |   0.627433   |
# +--------+--------------+
# |   0    |   0.320064   |
# +--------+--------------+
# |   0    |   0.27914    |
# +--------+--------------+
# |   0    |   0.225312   |
# +--------+--------------+
# |   1    |   0.45171    |
# +--------+--------------+
# |   1    |   0.407363   |
# +--------+--------------+
# |   0    |    0.146     |
# +--------+--------------+
# |   0    |   0.270309   |
# +--------+--------------+
# |   0    |   0.262943   |
# +--------+--------------+
# |   0    |    0.2115    |
# +--------+--------------+
# |   0    |  0.0205559   |
# +--------+--------------+
# |   0    |   0.334096   |
# +--------+--------------+
# |   0    |   0.291899   |
# +--------+--------------+
# |   1    |   0.49536    |
# +--------+--------------+
# |   1    |   0.358217   |
# +--------+--------------+
# |   0    |   0.223686   |
# +--------+--------------+
# |   0    |  0.0752822   |
# +--------+--------------+
# |   0    |   0.213806   |
# +--------+--------------+
# |   0    |   0.162911   |
# +--------+--------------+
# |   1    |   0.257932   |
# +--------+--------------+
# |   0    |   0.293521   |
# +--------+--------------+
# |   0    |   0.230313   |
# +--------+--------------+
# |   1    |   0.447298   |
# +--------+--------------+
# |   0    |   0.163358   |
# +--------+--------------+
# |   1    |   0.413025   |
# +--------+--------------+
# |   0    |  0.0796651   |
# +--------+--------------+
# |   0    |   0.296221   |
# +--------+--------------+
# |   0    |   0.103655   |
# +--------+--------------+
# |   0    |   0.206838   |
# +--------+--------------+
# |   0    |   0.204941   |
# +--------+--------------+
# |   0    |   0.262072   |
# +--------+--------------+
# |   0    |   0.205231   |
# +--------+--------------+
# |   0    |   0.101906   |
# +--------+--------------+
# |   0    |   0.108764   |
# +--------+--------------+
# |   0    |  0.0512774   |
# +--------+--------------+
# |   0    |  0.0997165   |
# +--------+--------------+
# |   1    |   0.305675   |
# +--------+--------------+
# |   0    |   0.231363   |
# +--------+--------------+
# |   0    |   0.144156   |
# +--------+--------------+
# |   0    |   0.168777   |
# +--------+--------------+
# |   1    |   0.345051   |
# +--------+--------------+
# |   1    |   0.368347   |
# +--------+--------------+
# |   0    |   0.22685    |
# +--------+--------------+
# |   0    |   0.157607   |
# +--------+--------------+
# |   0    |   0.230148   |
# +--------+--------------+
# |   0    |   0.134245   |
# +--------+--------------+
# |   0    |   0.126781   |
# +--------+--------------+
# |   1    |   0.561025   |
# +--------+--------------+
# |   0    |   0.137233   |
# +--------+--------------+
# |   0    |   0.185857   |
# +--------+--------------+
# |   0    |   0.187503   |
# +--------+--------------+
# |   0    |  0.0205559   |
# +--------+--------------+
# |   1    |   0.410338   |
# +--------+--------------+
# |   0    |   0.124151   |
# +--------+--------------+
# |   0    |   0.148195   |
# +--------+--------------+
# |   0    |   0.210485   |
# +--------+--------------+
# |   0    |   0.167247   |
# +--------+--------------+
# |   0    |   0.215702   |
# +--------+--------------+
# |   0    |   0.264815   |
# +--------+--------------+
# |   0    |   0.186455   |
# +--------+--------------+
# |   0    |   0.208257   |
# +--------+--------------+
# |   1    |   0.324964   |
# +--------+--------------+
# |   1    |   0.313668   |
# +--------+--------------+
# |   1    |   0.491866   |
# +--------+--------------+
# |   1    |   0.393433   |
# +--------+--------------+
# |   0    |   0.192723   |
# +--------+--------------+
# |   0    |   0.107004   |
# +--------+--------------+
# |   0    |   0.345435   |
# +--------+--------------+
# |   0    |   0.114445   |
# +--------+--------------+
# |   0    |   0.164097   |
# +--------+--------------+
# |   0    |  0.0914361   |
# +--------+--------------+
# |   0    |   0.292648   |
# +--------+--------------+
# |   0    |   0.17075    |
# +--------+--------------+
# |   1    |   0.471111   |
# +--------+--------------+
# |   1    |   0.416558   |
# +--------+--------------+
# |   0    |   0.265933   |
# +--------+--------------+
# |   0    |   0.145476   |
# +--------+--------------+
# |   1    |   0.383988   |
# +--------+--------------+
# |   0    |    0.2695    |
# +--------+--------------+
# |   0    |   0.122028   |
# +--------+--------------+
# |   0    |   0.21885    |
# +--------+--------------+
# |   1    |   0.656167   |
# +--------+--------------+
# |   1    |   0.379315   |
# +--------+--------------+
# |   0    |   0.128658   |
# +--------+--------------+
# |   0    |   0.220308   |
# +--------+--------------+
# |   0    |  0.0908292   |
# +--------+--------------+
# |   1    |   0.485921   |
# +--------+--------------+
# |   0    |   0.307041   |
# +--------+--------------+
# |   0    |   0.104001   |
# +--------+--------------+
# |   0    |   0.121741   |
# +--------+--------------+
# |   1    |   0.257932   |
# +--------+--------------+
# |   0    |   0.244633   |
# +--------+--------------+
# |   0    |   0.274847   |
# +--------+--------------+
# |   0    |   0.208248   |
# +--------+--------------+
# |   0    |   0.218543   |
# +--------+--------------+
# |   0    |   0.311632   |
# +--------+--------------+
# |   0    |   0.25208    |
# +--------+--------------+
# |   0    |   0.345435   |
# +--------+--------------+
# |   0    |   0.260157   |
# +--------+--------------+
# |   0    |   0.194805   |
# +--------+--------------+
# |   0    |   0.16543    |
# +--------+--------------+
# |   1    |   0.423164   |
# +--------+--------------+
# |   0    |   0.202531   |
# +--------+--------------+
# |   0    |   0.233793   |
# +--------+--------------+
# |   0    |   0.203727   |
# +--------+--------------+
# |   1    |   0.539109   |
# +--------+--------------+
# |   1    |   0.549136   |
# +--------+--------------+
# |   0    |   0.257079   |
# +--------+--------------+
# |   0    |   0.273407   |
# +--------+--------------+
# |   1    |   0.360571   |
# +--------+--------------+
# |   1    |   0.41198    |
# +--------+--------------+
# |   0    |   0.339856   |
# +--------+--------------+
# |   1    |   0.561153   |
# +--------+--------------+
# |   0    |   0.227002   |
# +--------+--------------+
# |   0    |   0.24954    |
# +--------+--------------+
# |   0    |   0.106005   |
# +--------+--------------+
# |   0    |   0.155916   |
# +--------+--------------+
# |   0    |   0.173877   |
# +--------+--------------+
# |   0    |   0.300639   |
# +--------+--------------+
# |   0    |   0.298457   |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   0    |   0.14523    |
# +--------+--------------+
# |   0    |   0.164312   |
# +--------+--------------+
# |   0    |   0.27456    |
# +--------+--------------+
# |   1    |   0.498189   |
# +--------+--------------+
# |   0    |   0.17586    |
# +--------+--------------+
# |   0    |   0.240981   |
# +--------+--------------+
# |   1    |   0.432732   |
# +--------+--------------+
# |   0    |   0.14636    |
# +--------+--------------+
# |   0    |   0.14802    |
# +--------+--------------+
# |   0    |   0.182798   |
# +--------+--------------+
# |   0    |   0.233313   |
# +--------+--------------+
# |   0    |   0.13768    |
# +--------+--------------+
# |   1    |   0.403572   |
# +--------+--------------+
# |   0    |   0.205166   |
# +--------+--------------+
# |   0    |   0.136057   |
# +--------+--------------+
# |   0    |   0.217141   |
# +--------+--------------+
# |   0    |   0.237693   |
# +--------+--------------+
# |   0    |   0.202028   |
# +--------+--------------+
# |   0    |   0.185221   |
# +--------+--------------+
# |   1    |   0.55952    |
# +--------+--------------+
# |   0    |   0.281728   |
# +--------+--------------+
# |   0    |   0.213972   |
# +--------+--------------+
# |   1    |   0.420915   |
# +--------+--------------+
# |   0    |   0.13426    |
# +--------+--------------+
# |   0    |   0.205264   |
# +--------+--------------+
# |   1    |   0.539624   |
# +--------+--------------+
# |   0    |   0.280072   |
# +--------+--------------+
# |   0    |   0.223071   |
# +--------+--------------+
# |   0    |   0.248518   |
# +--------+--------------+
# |   0    |   0.156856   |
# +--------+--------------+
# |   1    |   0.509097   |
# +--------+--------------+
# |   0    |   0.212923   |
# +--------+--------------+
# |   0    |   0.144419   |
# +--------+--------------+
# |   0    |   0.150599   |
# +--------+--------------+
# |   1    |   0.477258   |
# +--------+--------------+
# |   0    |   0.174805   |
# +--------+--------------+
# |   1    |   0.575916   |
# +--------+--------------+
# |   0    |   0.202817   |
# +--------+--------------+
# |   0    |   0.322119   |
# +--------+--------------+
# |   0    |   0.21693    |
# +--------+--------------+
# |   1    |   0.411317   |
# +--------+--------------+
# |   0    |   0.140637   |
# +--------+--------------+
# |   0    |   0.243647   |
# +--------+--------------+
# |   0    |  0.0988839   |
# +--------+--------------+
# |   0    |   0.248801   |
# +--------+--------------+
# |   0    |   0.204797   |
# +--------+--------------+
# |   1    |   0.313668   |
# +--------+--------------+
# |   0    |  0.0888077   |
# +--------+--------------+
# |   0    |   0.214956   |
# +--------+--------------+
# |   0    |   0.249547   |
# +--------+--------------+
# |   1    |   0.366283   |
# +--------+--------------+
# |   0    |  0.0688346   |
# +--------+--------------+
# |   0    |   0.170677   |
# +--------+--------------+
# |   0    |   0.224151   |
# +--------+--------------+
# |   1    |   0.57916    |
# +--------+--------------+
# |   1    |   0.447741   |
# +--------+--------------+
# |   0    |   0.231782   |
# +--------+--------------+
# |   1    |   0.55952    |
# +--------+--------------+
# |   0    |   0.214033   |
# +--------+--------------+
# |   1    |   0.484534   |
# +--------+--------------+
# |   0    |   0.194752   |
# +--------+--------------+
# |   0    |   0.194434   |
# +--------+--------------+
# |   0    |   0.185066   |
# +--------+--------------+
# |   0    |   0.170083   |
# +--------+--------------+
# |   0    |   0.214678   |
# +--------+--------------+
# |   0    |   0.124578   |
# +--------+--------------+
# |   0    |   0.172188   |
# +--------+--------------+
# |   0    |   0.225027   |
# +--------+--------------+
# |   0    |   0.152736   |
# +--------+--------------+
# |   0    |   0.220512   |
# +--------+--------------+
# |   0    |   0.191783   |
# +--------+--------------+
# |   0    |   0.185475   |
# +--------+--------------+
# |   0    |  0.0761485   |
# +--------+--------------+
# |   0    |   0.223408   |
# +--------+--------------+
# |   0    |  0.0549077   |
# +--------+--------------+
# |   1    |   0.509097   |
# +--------+--------------+
# |   0    |   0.143707   |
# +--------+--------------+
# |   0    |   0.252048   |
# +--------+--------------+
# |   0    |   0.100927   |
# +--------+--------------+
# |   1    |   0.440023   |
# +--------+--------------+
# |   0    |   0.091868   |
# +--------+--------------+
# |   0    |   0.136228   |
# +--------+--------------+
# |   0    |   0.252621   |
# +--------+--------------+
# |   0    |  0.0231763   |
# +--------+--------------+
# |   0    |   0.294133   |
# +--------+--------------+
# |   0    |   0.166774   |
# +--------+--------------+
# |   0    |  0.0863763   |
# +--------+--------------+
# |   0    |   0.232539   |
# +--------+--------------+
# |   0    |   0.252224   |
# +--------+--------------+
# |   0    |   0.170621   |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   1    |   0.324622   |
# +--------+--------------+
# |   0    |   0.15318    |
# +--------+--------------+
# |   0    |   0.288328   |
# +--------+--------------+
# |   0    |   0.193607   |
# +--------+--------------+
# |   0    |   0.22572    |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   0    |  0.0777394   |
# +--------+--------------+
# |   0    |   0.281071   |
# +--------+--------------+
# |   0    |   0.14762    |
# +--------+--------------+
# |   0    |   0.225595   |
# +--------+--------------+
# |   0    |  0.0515874   |
# +--------+--------------+
# |   1    |   0.327063   |
# +--------+--------------+
# |   0    |   0.167895   |
# +--------+--------------+
# |   1    |   0.309104   |
# +--------+--------------+
# |   0    |   0.181582   |
# +--------+--------------+
# |   1    |   0.417995   |
# +--------+--------------+
# |   1    |   0.460824   |
# +--------+--------------+
# |   0    |  0.0686226   |
# +--------+--------------+
# |   1    |   0.327595   |
# +--------+--------------+
# |   0    |   0.131219   |
# +--------+--------------+
# |   1    |   0.41741    |
# +--------+--------------+
# |   1    |   0.395569   |
# +--------+--------------+
# |   0    |   0.220884   |
# +--------+--------------+
# |   0    |   0.102023   |
# +--------+--------------+
# |   0    |   0.321996   |
# +--------+--------------+
# |   0    |   0.238774   |
# +--------+--------------+
# |   0    |   0.173248   |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   0    |  0.0599933   |
# +--------+--------------+
# |   0    |   0.172963   |
# +--------+--------------+
# |   0    |   0.224395   |
# +--------+--------------+
# |   0    |   0.281848   |
# +--------+--------------+
# |   0    |   0.181933   |
# +--------+--------------+
# |   0    |   0.20081    |
# +--------+--------------+
# |   1    |   0.276252   |
# +--------+--------------+
# |   0    |  0.0459629   |
# +--------+--------------+
# |   0    |   0.292694   |
# +--------+--------------+
# |   0    |   0.239141   |
# +--------+--------------+
# |   1    |   0.634456   |
# +--------+--------------+
# |   0    |  0.0187119   |
# +--------+--------------+
# |   0    |   0.25173    |
# +--------+--------------+
# Cost function:  0.3666622995206684
# Accuracy:  81.4070351758794 %

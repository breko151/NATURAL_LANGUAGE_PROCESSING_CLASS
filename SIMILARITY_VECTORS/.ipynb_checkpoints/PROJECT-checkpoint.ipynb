# %% [markdown]
# # Similarity
# **Suárez Pérez Juan Pablo**

# %% [markdown]
# ## Text Processing

# %%
# Import the libraries needed
from nlp_functions import text_processing as tp
from nlp_functions import word_association as wa

# %%
# Clean the corpus
tp.clean_corpus('./../EXCELSIOR_100_files/', './new_corpus/')

# %%
# Get clean corpus
text = tp.get_clean_text('./new_corpus/clean_corpus.txt')

# %% [markdown]
# ### Normalization

# %%
# Tokenize the text
words = tp.word_tokenize(text)
sents = tp.sentence_tokenize(text)

# %%
# Delete stop words
words = tp.delete_stop_words(words, './nlp_functions/stopwords_and_lemmas/stopwords_es.txt')
sents = tp.delete_stop_words_sents(sents, './nlp_functions/stopwords_and_lemmas/stopwords_es.txt')

# %%
# Lemmatize
words = tp.lemmatize(words, './nlp_functions/stopwords_and_lemmas/generate.txt')
sents = tp.lemmatize_sents(sents, './nlp_functions/stopwords_and_lemmas/generate.txt')

# %%
# Get Vocabulary
vocabulary = tp.get_vocabulary(words)

# %% [markdown]
# ## Numeric Representation

# %% [markdown]
# ### Similarities by Words

# %%
contexts = wa.get_contexts(vocabulary, words)
vectors = wa.get_vectors(vocabulary, contexts)
for w in vocabulary:
    try:
        wa.similar_words(w, vectors, aux_path = '_by_words', 
                         dot_product = True, cosine = True)
        print('Se completo', w)
    except Exception as e:
        print('Ocurrió el siguiente error:', e, 'en la palabra', w)
# Out:
# Se completo abandonar
# Se completo abandono
# Se completo abarcar
# Se completo abarrotar
# Se completo abascal
# Se completo abasto
# Se completo abatir
# Se completo abbasso
# Se completo abdicar
# Se completo aberrantes
# Se completo abierto
# Se completo abitia
# Se completo abono
# Se completo abordaje
# Se completo aborigen
# Se completo abraham
# Se completo abrego
# Se completo abril
# Se completo abrir
# Se completo absalón
# Se completo absoluto
# Se completo absuelto
# Se completo absurdamente
# Se completo absurdo
# Se completo abuelo
# Se completo abundante
# Se completo abundar
# Se completo aburto
# Se completo abusar
# Se completo abuso
# Se completo ac
# Se completo acabado
# Se completo acabar
# Se completo acaparar
# Se completo acapulco
# Se completo acarreo
# Se completo acaso
# Se completo accesible
# Se completo acceso
# Se completo accidente
# Se completo accionar
# Se completo accionista
# Se completo acción
# Se completo acelerar
# Se completo acento
# Se completo acentuado
# Se completo aceptabilidad
# Se completo aceptar
# Se completo acercar
# Se completo acero
# Se completo acertado
# Se completo acierto
# Se completo aclaración
# Se completo aclarar
# Se completo acompañado
# Se completo acompañamiento
# Se completo acompañar
# Se completo aconsejable
# Se completo aconsejar
# Se completo acontecimiento
# Se completo acopio
# Se completo acoplamiento
# Se completo acoplar
# Se completo acorde
# Se completo acotar
# Se completo acrecentar
# Se completo acreditar
# Se completo acreedor
# Se completo actitud
# Se completo activar
# Se completo actividad
# Se completo activo
# Se completo acto
# Se completo actor
# Se completo actriz
# Se completo actuación
# Se completo actual
# Se completo actualidad
# Se completo actualizar
# Se completo actualmente
# Se completo actuar
# Se completo acudir
# Se completo acuerdo
# Se completo acumulación
# Se completo acumular
# Se completo acusación
# Se completo acusado
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       3 for w in vocabulary:
#       4     try:
# ----> 5         wa.similar_words(w, vectors, aux_path = '_by_words',
#       6                          dot_product = True, cosine = True)
#       7         print('Se completo', w)
#       8     except Exception as e:
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:133, in similar_words(word, vectors, aux_path, tf_idf, dot_product, cosine)
#     130     s_dot_product(word, vectors, aux_path)
#     132 if cosine:
# --> 133     s_cosine(word, vectors, aux_path)
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:112, in s_cosine(word, vectors, aux_path)
#     110         similarities[W] = 0
#     111     else:
# --> 112         similarities[w] = np.dot(v, v2) / (np.linalg.norm(v) * np.linalg.norm(v2))
#     113 similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
#     114 with open('./cosine/similar_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
#
# File <__array_function__ internals>:5, in norm(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py:2530, in norm(x, ord, axis, keepdims)
#    2528     sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2529 else:
# -> 2530     sqnorm = dot(x, x)
#    2531 ret = sqrt(sqnorm)
#    2532 if keepdims:
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
probs = wa.get_vectors(vocabulary, contexts, prob = True)
for w in vocabulary:
    try:
        wa.similar_words(w, probs, aux_path = '_by_words_prob', 
                         dot_product = True, cosine = True)
        print('Se completo', w)
    except Exception as e:
        print('Ocurrió el siguiente error:', e, 'en la palabra', w)
# Out:
# Se completo abandonar
# Se completo abandono
# Se completo abarcar
# Se completo abarrotar
# Se completo abascal
# Se completo abasto
# Se completo abatir
# Se completo abbasso
# Se completo abdicar
# Se completo aberrantes
# Se completo abierto
# Se completo abitia
# Se completo abono
# Se completo abordaje
# Se completo aborigen
# Se completo abraham
# Se completo abrego
# Se completo abril
# Se completo abrir
# Se completo absalón
# Se completo absoluto
# Se completo absuelto
# Se completo absurdamente
# Se completo absurdo
# Se completo abuelo
# Se completo abundante
# Se completo abundar
# Se completo aburto
# Se completo abusar
# Se completo abuso
# Se completo ac
# Se completo acabado
# Se completo acabar
# Se completo acaparar
# Se completo acapulco
# Se completo acarreo
# Se completo acaso
# Se completo accesible
# Se completo acceso
# Se completo accidente
# Se completo accionar
# Se completo accionista
# Se completo acción
# Se completo acelerar
# Se completo acento
# Se completo acentuado
# Se completo aceptabilidad
# Se completo aceptar
# Se completo acercar
# Se completo acero
# Se completo acertado
# Se completo acierto
# Se completo aclaración
# Se completo aclarar
# Se completo acompañado
# Se completo acompañamiento
# Se completo acompañar
# Se completo aconsejable
# Se completo aconsejar
# Se completo acontecimiento
# Se completo acopio
# Se completo acoplamiento
# Se completo acoplar
# Se completo acorde
# Se completo acotar
# Se completo acrecentar
# Se completo acreditar
# Se completo acreedor
# Se completo actitud
# Se completo activar
# Se completo actividad
# Se completo activo
# Se completo acto
# Se completo actor
# Se completo actriz
# Se completo aptitud
# Se completo apuntar
# Se completo aquejar
# Se completo aquel
# Se completo aquella
# Se completo aquello
# Se completo aquellos
# Se completo aquél
# Se completo aquí
# Se completo ara
# Se completo aragón
# Se completo arancel
# Se completo arbitral
# Se completo arbitrario
# Se completo arca
# Se completo archivo
# Se completo arco
# Se completo arder
# Se completo ardid
# Se completo arena
# Se completo argentina
# Se completo argumentar
# Se completo argumento
# Se completo aria
# Se completo arizmendi
# Se completo arma
# Se completo armada
# Se completo armado
# Se completo armando
# Se completo armonía
# Se completo armónicamente
# Se completo armónico
# Se completo arnault
# Se completo arqueológico
# Se completo arquitecto
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       2 for w in vocabulary:
#       3     try:
# ----> 4         wa.similar_words(w, probs, aux_path = '_by_words_prob',
#       5                          dot_product = True, cosine = True)
#       6         print('Se completo', w)
#       7     except Exception as e:
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:130, in similar_words(word, vectors, aux_path, tf_idf, dot_product, cosine)
#     120 """
#     121     The Pipline to get similarities.
#     122     word: the word you want to get similaritie.
#    (...)
#     127     tf_idf: boolean, if you want to get similarities by this method.
#     128 """
#     129 if dot_product:
# --> 130     s_dot_product(word, vectors, aux_path)
#     132 if cosine:
#     133     s_cosine(word, vectors, aux_path)
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:91, in s_dot_product(word, vectors, aux_path)
#      89 v = vectors[word]
#      90 for w in vectors.keys():
# ---> 91     similarities[w] = np.dot(vectors[w], v)
#      92 similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
#      93 with open('./dot_product/similar_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Similarities by Sents

# %%
contexts = wa.get_contexts_sents(vocabulary, sents)
vectors = wa.get_vectors(vocabulary, contexts)
for w in vocabulary:
    try:
        wa.similar_words(w, vectors, aux_path = '_by_sents', 
                        dot_product = True, cosine = True)
        print('Se completo', w)
    except Exception as e:
        print('Ocurrió el siguiente error:', e, 'en la palabra', w)
# Out:
# Se completo abandonar
# Se completo abandono
# Se completo abarcar
# Se completo abarrotar
# Se completo abascal
# Se completo abasto
# Se completo abatir
# Se completo abbasso
# Se completo abdicar
# Se completo aberrantes
# Se completo abierto
# Se completo abitia
# Se completo abono
# Se completo abordaje
# Se completo aborigen
# Se completo abraham
# Se completo abrego
# Se completo abril
# Se completo abrir
# Se completo absalón
# Se completo absoluto
# Se completo absuelto
# Se completo absurdamente
# Se completo absurdo
# Se completo abuelo
# Se completo abundante
# Se completo abundar
# Se completo aburto
# Se completo abusar
# Se completo abuso
# Se completo ac
# Se completo acabado
# Se completo acabar
# Se completo acaparar
# Se completo acapulco
# Se completo acarreo
# Se completo acaso
# Se completo accesible
# Se completo acceso
# Se completo accidente
# Se completo accionar
# Se completo accionista
# Se completo acción
# Se completo acelerar
# Se completo acento
# Se completo acentuado
# Se completo aceptabilidad
# Se completo aceptar
# Se completo acercar
# Se completo acero
# Se completo acertado
# Se completo acierto
# Se completo aclaración
# Se completo aclarar
# Se completo acompañado
# Se completo acompañamiento
# Se completo acompañar
# Se completo aconsejable
# Se completo aconsejar
# Se completo acontecimiento
# Se completo acopio
# Se completo acoplamiento
# Se completo acoplar
# Se completo acorde
# Se completo acotar
# Se completo acrecentar
# Se completo acreditar
# Se completo acreedor
# Se completo actitud
# Se completo activar
# Se completo actividad
# Se completo activo
# Se completo acto
# Se completo actor
# Se completo actriz
# Se completo actuación
# Se completo actual
# Se completo actualidad
# Se completo actualizar
# Se completo actualmente
# Se completo actuar
# Se completo acudir
# Se completo acuerdo
# Se completo acumulación
# Se completo acumular
# Se completo acusación
# Se completo acusado
# Se completo acusar
# Se completo adaptar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       3 for w in vocabulary:
#       4     try:
# ----> 5         wa.similar_words(w, vectors, aux_path = '_by_sents',
#       6                         dot_product = True, cosine = True)
#       7         print('Se completo', w)
#       8     except Exception as e:
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:133, in similar_words(word, vectors, aux_path, tf_idf, dot_product, cosine)
#     130     s_dot_product(word, vectors, aux_path)
#     132 if cosine:
# --> 133     s_cosine(word, vectors, aux_path)
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:112, in s_cosine(word, vectors, aux_path)
#     110         similarities[w] = 0
#     111     else:
# --> 112         similarities[w] = np.dot(v, v2) / (np.linalg.norm(v) * np.linalg.norm(v2))
#     113 similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
#     114 with open('./cosine/similar_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
#
# File <__array_function__ internals>:5, in norm(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py:2517, in norm(x, ord, axis, keepdims)
#    2514 x = asarray(x)
#    2516 if not issubclass(x.dtype.type, (inexact, object_)):
# -> 2517     x = x.astype(float)
#    2519 # Immediately handle some default, simple, fast, and common cases.
#    2520 if axis is None:
#
# KeyboardInterrupt:

# %%
probs = wa.get_vectors(vocabulary, contexts, prob = True)
for w in vocabulary:
    try:
        wa.similar_words(w, probs, aux_path = '_by_sents_prob', 
                        dot_product = True, cosine = True)
        print('Se completo', w)
    except Exception as e:
        print('Ocurrió el siguiente error:', e, 'en la palabra', w)
# Out:
# Se completo abandonar
# Se completo abandono
# Se completo abarcar
# Se completo abarrotar
# Se completo abascal
# Se completo abasto
# Se completo abatir
# Se completo abbasso
# Se completo abdicar
# Se completo aberrantes
# Se completo abierto
# Se completo abitia
# Se completo abono
# Se completo abordaje
# Se completo aborigen
# Se completo abraham
# Se completo abrego
# Se completo abril
# Se completo abrir
# Se completo absalón
# Se completo absoluto
# Se completo absuelto
# Se completo absurdamente
# Se completo absurdo
# Se completo abuelo
# Se completo abundante
# Se completo abundar
# Se completo aburto
# Se completo abusar
# Se completo abuso
# Se completo ac
# Se completo acabado
# Se completo acabar
# Se completo acaparar
# Se completo acapulco
# Se completo acarreo
# Se completo acaso
# Se completo accesible
# Se completo acceso
# Se completo accidente
# Se completo accionar
# Se completo accionista
# Se completo acción
# Se completo acelerar
# Se completo acento
# Se completo acentuado
# Se completo aceptabilidad
# Se completo aceptar
# Se completo acercar
# Se completo acero
# Se completo acertado
# Se completo acierto
# Se completo aclaración
# Se completo aclarar
# Se completo acompañado
# Se completo acompañamiento
# Se completo acompañar
# Se completo aconsejable
# Se completo aconsejar
# Se completo acontecimiento
# Se completo acopio
# Se completo acoplamiento
# Se completo acoplar
# Se completo acorde
# Se completo acotar
# Se completo acrecentar
# Se completo acreditar
# Se completo acreedor
# Se completo actitud
# Se completo activar
# Se completo actividad
# Se completo activo
# Se completo acto
# Se completo actor
# Se completo actriz
# Se completo actuación
# Se completo actual
# Se completo actualidad
# Se completo actualizar
# Se completo actualmente
# Se completo actuar
# Se completo acudir
# Se completo acuerdo
# Se completo acumulación
# Se completo acumular
# Se completo acusación
# Se completo acusado
# Se completo acusar
# Se completo adaptar
# Se completo adecuadamente
# Se completo adecuado
# Se completo adelante
# Se completo además
# Se completo ades
# Se completo adeudos
# Se completo adicional
# Se completo adición
# Se completo adjudicar
# Se completo adjunta
# Se completo adjunto
# Se completo administración
# Se completo administrador
# Se completo administradora
# Se completo administrativa
# Se completo administrativo
# Se completo admirar
# Se completo admitir
# Se completo adolf
# Se completo adolfo
# Se completo adoptar
# Se completo adornar
# Se completo adquirir
# Se completo adquisición
# Se completo adquisitivo
# Se completo adreessen
# Se completo adrián
# Se completo aducir
# Se completo adulto
# Se completo advenedizo
# Se completo advenimiento
# Se completo adverso
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       2 for w in vocabulary:
#       3     try:
# ----> 4         wa.similar_words(w, probs, aux_path = '_by_sents_prob',
#       5                         dot_product = True, cosine = True)
#       6         print('Se completo', w)
#       7     except Exception as e:
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:130, in similar_words(word, vectors, aux_path, tf_idf, dot_product, cosine)
#     120 """
#     121     The Pipline to get similarities.
#     122     word: the word you want to get similaritie.
#    (...)
#     127     tf_idf: boolean, if you want to get similarities by this method.
#     128 """
#     129 if dot_product:
# --> 130     s_dot_product(word, vectors, aux_path)
#     132 if cosine:
#     133     s_cosine(word, vectors, aux_path)
#
# File ~\Documents\Scripts_Pyhton\NATURAL_LANGUAGE_PROCESSING_CLASS\PROJECT\nlp_functions\word_association.py:91, in s_dot_product(word, vectors, aux_path)
#      89 v = vectors[word]
#      90 for w in vectors.keys():
# ---> 91     similarities[w] = np.dot(vectors[w], v)
#      92 similarities = (sorted(similarities.items(), key = lambda item: item[1], reverse = True))
#      93 with open('./dot_product/similar_to_' + word + aux_path + '.txt', 'w', encoding = 'utf-8') as f:
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Final

# %%
# Words
contexts_1 = wa.get_contexts(vocabulary, words)
probs_1 = wa.get_vectors(vocabulary, contexts_1, prob = True)
# Sentences
contexts_2 = wa.get_contexts_sents(vocabulary, sents)
probs_2 = wa.get_vectors(vocabulary, contexts_2, prob = True)

# %%
word = "abandonar"
try:
    # Words
    wa.similar_words(word, probs_1, aux_path = '_by_words_prob_end', 
                    dot_product = True, cosine = True)
    print('Se completo', word, 'palabras')
    # Sents
    wa.similar_words(word, probs_2, aux_path = '_by_sents_prob_end', 
                    dot_product = True, cosine = True)
    print('Se completo', word, 'oraciones')
except Exception as e:
    print('Ocurrió el siguiente error:', e, 'en la palabra', word)
# Out:
# Se completo abandonar palabras
# Se completo abandonar oraciones

# %%
sents[1]
# Out:
# 'ciertamente nombre circunstancia luis donaldo colosio llenar insistentemente volumen espacio medio comunicación'

# %% [markdown]
# # Similarity by BM25
# **Suárez Pérez Juan Pablo**

# %% [markdown]
# ## Text Processing

# %%
# Import the libraries needed
from nlp_functions import text_processing as tp
from nlp_functions import word_association as wa
from nlp_functions import article_segmentation as arse
from nlp_functions import mining_topics as mt

# %%
# Clean the corpus
tp.clean_corpus('./../EXCELSIOR_100_files/', './new_corpus/', 1)

# %%
# Get clean corpus
    # Delete HTML Tags.
    # Lower words.
text = tp.get_clean_text('./new_corpus/clean_e960402_mod_corpus.txt')

# %%
# Sentences segmentation
# Split Sentences
# Delete Special Caracters
sents = tp.sentence_tokenize(text)

# %%
# Delete Stop Words
clean_sents = tp.delete_stop_words_sents(sents, './nlp_functions/stopwords_and_lemmas/stopwords_es.txt')

# %%
# Lemmatize
lemmatize_sents = tp.lemmatize_sents(clean_sents, './nlp_functions/stopwords_and_lemmas/generate.txt')

# %%
# Get Vocabulary
vocabulary = tp.get_vocabulary_by_sents(lemmatize_sents)
# Out:
# Vocabulary size: 4770

# %% [markdown]
# ## Mining Articles and Titles

# %%
titles = arse.get_titles('./../EXCELSIOR_100_files/', './titles/', 1)

# %%
articles = arse.get_articles('./../EXCELSIOR_100_files/', 1)

# %% [markdown]
# ### Normalize articles

# %%
tokenize_articles = list()
for article in articles:
    tokenize_articles.append(tp.sentence_tokenize(article))

# %%
clean_articles = list()
for article in tokenize_articles:
    clean_articles.append(tp.delete_stop_words_sents(article, './nlp_functions/stopwords_and_lemmas/stopwords_es.txt'))

# %%
lemmatize_articles = list()
for article in clean_articles:
    lemmatize_articles.append(tp.lemmatize_sents(article, './nlp_functions/stopwords_and_lemmas/generate.txt'))

# %% [markdown]
# ## Mining Topics

# %%
most_freq_words_prob = mt.get_most_freq_words_prob(lemmatize_sents, vocabulary)

# %%
most_freq_words = mt.get_most_freq_words(lemmatize_sents, vocabulary)

# %%
context = wa.get_contexts_sents(vocabulary, lemmatize_sents)
bm25_vectors = wa.get_vectors(vocabulary, context)
idf = wa.get_idf(bm25_vectors)

# %%
most_freq_words_tf_idf = mt.get_most_freq_words_tf_idf(idf, most_freq_words_prob, vocabulary)

# %% [markdown]
# ## Distribution of Topics in Documents

# %%
topics = ['méxico', 'gobierno', 'internet', 'política', 'dólar']
dist_topics = mt.get_distribution(titles, lemmatize_articles, topics)

# %%
for k, v in dist_topics.items():
    if k[-2:] == '\n':
        print(k[:-2])
    else:
        print(k)
    for k2, v2 in v.items():
        print('\t', k2, ':', v2)
# Out:
# semana doliente
#
# 	 méxico : 0.5
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.5
# 	 dólar : 0.0
# desde la medicina
#
# 	 méxico : 0.5
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.5
# la nueva realidad
#
# 	 méxico : 0.6666666666666666
# 	 gobierno : 0.3333333333333333
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# hace 25 años
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# hipótesis y dudas
#
# 	 méxico : 0.5
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.5
# 	 dólar : 0.0
# un lenguaje de papel
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# hace 50 años
#
# 	 méxico : 0.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 1.0
# ¿amos más tolerantes?
#
# 	 méxico : 0.0
# 	 gobierno : 0.8333333333333334
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.16666666666666666
# equilibrio doctrina-acción
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# estamos mal, pero pagamos
#
# 	 méxico : 1.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# la ctm critica las alzas
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# economía en crisis
#
# 	 méxico : 0.0
# 	 gobierno : 0.6666666666666666
# 	 internet : 0.0
# 	 política : 0.3333333333333333
# 	 dólar : 0.0
# liberan areas protegidas
#
# 	 méxico : 0.3333333333333333
# 	 gobierno : 0.3333333333333333
# 	 internet : 0.0
# 	 política : 0.3333333333333333
# 	 dólar : 0.0
# bajó 19% la inversión pública en 95; desempleo de 1.6 millones
#
# 	 méxico : 0.3333333333333333
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.6666666666666666
# censura la ctm las alzas; "endureceremos" la lucha por el salario móvil: fidel
#
# 	 méxico : 0.6666666666666666
# 	 gobierno : 0.3333333333333333
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# ip: repuntará el mercado interno con el alza salarial
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# recuperación económica, si se concreta la reforma electoral
#
# 	 méxico : 0.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 1.0
# 	 dólar : 0.0
# aprobó el senado las reformas para expedir la ley contra la delincuencia
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# el valle de méxico se quedó sin 80% de sus areas verdes originales: pvem
#
# 	 méxico : 0.8
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.2
# 	 dólar : 0.0
# los signos de sabines
#
# 	 méxico : 0.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 1.0
# 	 dólar : 0.0
# aumentó 2.9% el indice de precios metropolitano en marzo: ci
#
# 	 méxico : 0.35714285714285715
# 	 gobierno : 0.32142857142857145
# 	 internet : 0.0
# 	 política : 0.2857142857142857
# 	 dólar : 0.03571428571428571
# se mantiene la baja de tasas de interés
#
# 	 méxico : 1.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# ¿está fuera de control?
#
# 	 méxico : 0.5
# 	 gobierno : 0.25
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.25
# "existen recursos para prestar; falta capitalizar a unidades productivas"
#
# 	 méxico : 0.75
# 	 gobierno : 0.25
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# cayó más de 70% el margen de utilidad de la banca en 95; se ubicó en 0.93%
#
# 	 méxico : 0.3333333333333333
# 	 gobierno : 0.3333333333333333
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.3333333333333333
# enfrenta eu presiones inflacionaria
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# desde el piso de remates
#
# 	 méxico : 0.6666666666666666
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.16666666666666666
# 	 dólar : 0.16666666666666666
# la contracción de la demanda no ha podido frenar la inflación
#
# 	 méxico : 0.6
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.4
# carta al procurador general de la república
#
# 	 méxico : 0.3333333333333333
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.6666666666666666
# 	 dólar : 0.0
# renuncia al partido de la revolución democrática
#
# 	 méxico : 1.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# crear nueva constitución, imperiosa necesidad
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# comenta lo sucedido por la caída del comunismo
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# "el vecino realiza la campaña antinarcóticos más efectiva"
#
# 	 méxico : 0.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 1.0
# 	 dólar : 0.0
# se suspenderá jueves y viernes el programa hoy no circula: palazuelos
#
# 	 méxico : 0.5
# 	 gobierno : 0.5
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# el neoliberalismo ha traído consigo "consecuencias perversas": l. boff
#
# 	 méxico : 0.875
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.125
# m. madero o'brien se declara inocente de daño patrimonial por 34 millones de dls.
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# la crisis económica, tumba del pri en los comicios de 1997: oposición
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# josé f. ruiz massieu "era creyente y operador" del modelo salinista: luengo
#
# 	 méxico : 0.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 1.0
# básico, el apoyo del médico residente en el avance de la medicina social: aguilera
#
# 	 méxico : 0.0
# 	 gobierno : 0.3333333333333333
# 	 internet : 0.0
# 	 política : 0.6666666666666666
# 	 dólar : 0.0
# "registra el agua del df altos indices de salmonella y shigela"
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# el desempleo en municipios de jalisco y zacatecas expulsa a familias hacia eu
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# venció el plazo para el pago de la tenencia; recargos y tasa inflacionaria a los morosos
#
# 	 méxico : 1.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# continúa el exodo de capitalinos a razón de 5 mil vehículos por hora, en promedio
#
# 	 méxico : 0.058823529411764705
# 	 gobierno : 0.11764705882352941
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.8235294117647058
# xavier ponce de león, nuevo subdelegado en la cuauhtémoc
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# el precio de la gasolina magna sin se ubicó desde ayer en $2.47 por litro
#
# 	 méxico : 0
# 	 gobierno : 0
# 	 internet : 0
# 	 política : 0
# 	 dólar : 0
# reportan siete sismos en las ultimas 48 horas; la intensidad entre 4.4 y 5.4 grados richter
#
# 	 méxico : 0.0
# 	 gobierno : 1.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
# designan a m. espinoza contreras obispo de la diócesis de tehuacán
#
# 	 méxico : 1.0
# 	 gobierno : 0.0
# 	 internet : 0.0
# 	 política : 0.0
# 	 dólar : 0.0
